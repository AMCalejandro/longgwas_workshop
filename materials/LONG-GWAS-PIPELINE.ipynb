# %% [markdown]
# # Set up
#
# - Download / Install libraries needed in the workspace

# %% [markdown]
# ## Load modules

# %%
# Use the os package to interact with the environment
import os

# Use StringIO for working with file contents
from io import StringIO

# Bring in Pandas for Dataframe functionality
import pandas as pd

# numpy for basics
import numpy as np

# Enable IPython to display matplotlib graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# Import seaborn for plots
import seaborn as sns

# Enable interaction with the FireCloud API
from firecloud import api as fapi

# Import the iPython HTML rendering for displaying links to Google Cloud Console
from IPython.core.display import display, HTML

# Import urllib modules for building URLs to Google Cloud Console
import urllib.parse
# Out:
# /tmp/ipykernel_185/4207620771.py:24: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %% [markdown]
# ## Load functions

# %%
# Utility routine for printing a shell command before executing it
def shell_do(command):
    print(f'Executing: {command}')
    # !$command

# Utility routines for reading files from Google Cloud Storage
def gcs_read_file(path):
    """Return the contents of a file in GCS"""
    contents = !gsutil -u {BILLING_PROJECT_ID} cat {path}
    return '\n'.join(contents)
    
def gcs_read_csv(path, sep=None):
    """Return a DataFrame from the contents of a delimited file in GCS"""
    return pd.read_csv(StringIO(gcs_read_file(path)), sep=sep, engine='python')

# Utility routine for display a message and a link
def display_html_link(description, link_text, url):
    html = f'''
    <p>
    </p>
    <p>
    {description}
    <a target=_blank href="{url}">{link_text}</a>.
    </p>
    '''

    display(HTML(html))
    
# Utility routine for displaying a message and link to Cloud Console
def link_to_cloud_console_gcs(description, link_text, gcs_path):
    url = '{}?{}'.format(
        os.path.join('https://console.cloud.google.com/storage/browser',
                     gcs_path.replace("gs://","")),
        urllib.parse.urlencode({'userProject': BILLING_PROJECT_ID}))

    display_html_link(description, link_text, url)

# %% [markdown]
# ### Define bash and python environmental variables / WD

# %% [markdown]
# ##### bash

# %%
# %%bash
#
# mkdir -p /home/jupyter/longwas_workdir
# mkdir -p  /home/jupyter/longwas_workdir/corriellnetpd_geno
# mkdir -p /home/jupyter/longwas_workdir/clinical_qc
#
# mkdir -p /home/jupyter/longwas_workdir
# mkdir -p  /home/jupyter/longwas_workdir/ppmi_geno
#
# mkdir -p /home/jupyter/longwas_workdir
# mkdir -p  /home/jupyter/longwas_workdir/pdgen_geno
#
#
# WORK_DIR=/home/jupyter/longwas_workdir
# cd $WORK_DIR

# %% [markdown]
# ##### python

# %%
WORK_DIR = "/home/jupyter/longwas_workdir/"

# %% [markdown]
# ## Get some environmental variables with GCP project metadata and paths to buckets

# %%
BILLING_PROJECT_ID = os.environ['GOOGLE_PROJECT']
WORKSPACE_NAMESPACE = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE_NAME = os.environ['WORKSPACE_NAME']
WORKSPACE_BUCKET = os.environ['WORKSPACE_BUCKET']
#WORKSPACE_ATTRIBUTES = fapi.get_workspace(WORKSPACE_NAMESPACE, WORKSPACE_NAME).json().get('workspace',{}).get('attributes',{})

print(BILLING_PROJECT_ID)
print(WORKSPACE_NAMESPACE)
print(WORKSPACE_NAME)
print(WORKSPACE_BUCKET)


## GP2 v3.0
GP2_RELEASE_PATH = 'gs://gp2tier2/release3_31102022'
GP2_CLINICAL_RELEASE_PATH = f'{GP2_RELEASE_PATH}/clinical_data'
GP2_IMPUTED_GENO_PATH = f'{GP2_RELEASE_PATH}/imputed_genotypes'
GP2_WGS_PATH = f'{GP2_RELEASE_PATH}/wgs/plink/bfiles'
link_to_cloud_console_gcs("Access GP2 bucket: ", "HERE", GP2_RELEASE_PATH)

## NEXTFLOW WS BUCKET
NEXTFLOW_WD_BUCKET = 'gs://long-gwas'

link_to_cloud_console_gcs("Take a look at the Nextflow WD bucket: ", "HERE!", NEXTFLOW_WD_BUCKET)

link_to_cloud_console_gcs("Take a look at the workspace bucket: ", "HERE!", WORKSPACE_BUCKET)
# Out:
# terra-05d0f4c6
# GP2-Bioinformatics-Courses
# MEXICO_WORKSHOP
# gs://fc-secure-cbdcecad-15a2-473b-8df9-841de062728d
#     <p>
#     </p>
#     <p>
#     Access GP2 bucket:
#     <a target=_blank href="https://console.cloud.google.com/storage/browser/gp2tier2/release3_31102022?userProject=terra-05d0f4c6">HERE</a>.
#     </p>
#     <p>
#     </p>
#     <p>
#     Take a look at the Nextflow WD bucket:
#     <a target=_blank href="https://console.cloud.google.com/storage/browser/long-gwas?userProject=terra-05d0f4c6">HERE!</a>.
#     </p>
#     <p>
#     </p>
#     <p>
#     Take a look at the workspace bucket:
#     <a target=_blank href="https://console.cloud.google.com/storage/browser/fc-secure-cbdcecad-15a2-473b-8df9-841de062728d?userProject=terra-05d0f4c6">HERE!</a>.
#     </p>

# %% [markdown]
# ### Get plink binaries

# %%
# %%bash
#
# mkdir -p ~/tools
# cd ~/tools
#
# if test -e /home/jupyter/tools/plink; then
# echo "Plink is already installed in /home/jupyter/tools/"
#
# else
# echo -e "Dowloading plink \n    -------"
# wget -N http://s3.amazonaws.com/plink1-assets/plink_linux_x86_64_20190304.zip
# unzip -o plink_linux_x86_64_20190304.zip
# echo -e "\n plink downloaded and unzipped in /home/jupyter/tools \n "
#
# fi
#
#
# if test -e /home/jupyter/tools/plink2; then
# echo "Plink is already installed in /home/jupyter/tools/"
#
# else
# echo -e "Dowloading plink2 \n    -------"
# wget -N https://s3.amazonaws.com/plink2-assets/alpha3/plink2_linux_avx2_20220603.zip
# unzip -o plink2_linux_avx2_20220603.zip
# echo -e "\n plink2 downloaded and unzipped in /home/jupyter/tools \n "
#
# fi
#
# cd ~
# Out:
# Plink is already installed in /home/jupyter/tools/
# Plink is already installed in /home/jupyter/tools/

# %% [markdown]
# # Load the data

# %% [markdown]
# ### Get access to the clinical data

# %%
netpd = gcs_read_csv(f'{WORKSPACE_BUCKET}/netpdls1/NET_PD_LS1_20230627_processed_unreviewed.csv')
netpdcorriell_ids = gcs_read_csv(f'{WORKSPACE_BUCKET}/netpdls1/IDmatch.csv')

print(netpdcorriell_ids)

netpdcorriell = netpdcorriell_ids.merge(netpd, on = 'participant_id')
netpdcorriell.info()
netpdcorriell.head()

# %% [markdown]
# ### Get access tho imputed data
#
#
# - Copy data on workspace
# - Filter according to the

# %%
get_names = shell_do(f'gsutil -u {BILLING_PROJECT_ID} -m cp -R {GP2_IMPUTED_GENO_PATH}/EUR/chr7* {WORK_DIR}')
# Out:
# Executing: gsutil -u terra-05d0f4c6 -m cp -R gs://gp2tier2/release3_31102022/imputed_genotypes/EUR/chr7* /home/jupyter/longwas_workdir/
# Copying gs://gp2tier2/release3_31102022/imputed_genotypes/EUR/chr7_EUR_release3.pgen...
# Copying gs://gp2tier2/release3_31102022/imputed_genotypes/EUR/chr7_EUR_release3.psam...
# Copying gs://gp2tier2/release3_31102022/imputed_genotypes/EUR/chr7_EUR_release3.log...
# Copying gs://gp2tier2/release3_31102022/imputed_genotypes/EUR/chr7_EUR_release3.pvar...
# - [4/4 files][  5.9 GiB/  5.9 GiB] 100% Done  57.4 MiB/s ETA 00:00:00
# Operation completed over 4 objects/5.9 GiB.

# %% [markdown]
# ### Filter Corriell IDs and then convert to VCF files as this is the standard inpiut the tool uses

# %% [markdown]
# #### Get the IDs

# %%
corriell_keep = list(netpdcorriell_ids['GP2sampleID'])
corriell_keep

with open(f'{WORK_DIR}corriell_ids.txt', 'w') as file:
    for myid in corriell_keep:
        # write each item on a new line
        file.write("%s\n" % myid)
    print('Done')

# %%
# %%bash -s "$WORK_DIR"
# cd $1
# tail corriell_ids.txt
# Out:
# CORIELL_003785_s1
# CORIELL_004157_s1
# CORIELL_003667_s1
# CORIELL_003501_s1
# CORIELL_003877_s1
# CORIELL_003260_s1
# CORIELL_003446_s1
# CORIELL_004118_s1
# CORIELL_003419_s1
# CORIELL_003514_s1

# %% [markdown]
# #### Perform the filtering

# %%
# %%bash -s "$WORK_DIR"
# cd $1
# corriellnetpd_geno
# for chnum in {1..22};
# do
# /home/jupyter/tools/plink2 \
#     --pfile EUR/chr"$chnum"_EUR_release3 \
#     --keep corriell_ids.txt \
#     --make-pgen \
#     --out corriellnetpd_geno/corriell_chr"$chnum"_EUR_release3
# done
# Out:
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr13_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr13_EUR_release3
#   --pfile EUR/chr13_EUR_release3
#
# Start time: Sun Jul  2 18:18:38 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr13_EUR_release3.psam.
# 711517 variants loaded from EUR/chr13_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr13_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:19:16 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr14_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr14_EUR_release3
#   --pfile EUR/chr14_EUR_release3
#
# Start time: Sun Jul  2 18:19:17 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr14_EUR_release3.psam.
# 634312 variants loaded from EUR/chr14_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr14_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:21:16 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr15_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr15_EUR_release3
#   --pfile EUR/chr15_EUR_release3
#
# Start time: Sun Jul  2 18:21:17 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr15_EUR_release3.psam.
# 570161 variants loaded from EUR/chr15_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr15_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:23:11 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr16_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr16_EUR_release3
#   --pfile EUR/chr16_EUR_release3
#
# Start time: Sun Jul  2 18:23:12 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr16_EUR_release3.psam.
# 622521 variants loaded from EUR/chr16_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr16_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:25:20 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr17_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr17_EUR_release3
#   --pfile EUR/chr17_EUR_release3
#
# Start time: Sun Jul  2 18:25:21 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr17_EUR_release3.psam.
# 557796 variants loaded from EUR/chr17_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr17_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:27:12 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr18_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr18_EUR_release3
#   --pfile EUR/chr18_EUR_release3
#
# Start time: Sun Jul  2 18:27:12 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr18_EUR_release3.psam.
# 558948 variants loaded from EUR/chr18_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr18_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:29:07 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr19_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr19_EUR_release3
#   --pfile EUR/chr19_EUR_release3
#
# Start time: Sun Jul  2 18:29:07 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr19_EUR_release3.psam.
# 449087 variants loaded from EUR/chr19_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr19_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:30:46 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr20_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr20_EUR_release3
#   --pfile EUR/chr20_EUR_release3
#
# Start time: Sun Jul  2 18:30:47 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr20_EUR_release3.psam.
# 445947 variants loaded from EUR/chr20_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr20_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:32:18 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr21_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr21_EUR_release3
#   --pfile EUR/chr21_EUR_release3
#
# Start time: Sun Jul  2 18:32:19 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr21_EUR_release3.psam.
# 269941 variants loaded from EUR/chr21_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr21_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:33:19 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr22_EUR_release3.log.
# Options in effect:
#   --keep corriell_ids.txt
#   --make-pgen
#   --out corriellnetpd_geno/corriell_chr22_EUR_release3
#   --pfile EUR/chr22_EUR_release3
#
# Start time: Sun Jul  2 18:33:19 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 11002 samples (4271 females, 6731 males; 11002 founders) loaded from
# EUR/chr22_EUR_release3.psam.
# 271576 variants loaded from EUR/chr22_EUR_release3.pvar.
# 1 binary phenotype loaded (6852 cases, 3875 controls).
# --keep: 422 samples remaining.
# 422 samples (156 females, 266 males; 422 founders) remaining after main
# filters.
# 422 cases and 0 controls remaining after main filters.
# Writing corriellnetpd_geno/corriell_chr22_EUR_release3.psam ... done.
# done.
# done.
# End time: Sun Jul  2 18:34:21 2023
# bash: line 2: corriellnetpd_geno: command not found

# %% [markdown]
# #### Creat VCFs

# %%
# %%bash -s "$WORK_DIR"
# cd $1
#
# for chnum in {1..22};
# do
# /home/jupyter/tools/plink2 \
#     --pfile corriellnetpd_geno/corriell_chr"$chnum"_EUR_release3 \
#     --recode vcf \
#     --out corriellnetpd_geno/corriell_chr"$chnum"_EUR_release3
# done
# Out:
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr1_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr1_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr1_EUR_release3
#
# Start time: Sun Jul  2 18:46:00 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr1_EUR_release3.psam.
# 1567941 variants loaded from
# corriellnetpd_geno/corriell_chr1_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:46:27 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr2_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr2_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr2_EUR_release3
#
# Start time: Sun Jul  2 18:46:27 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr2_EUR_release3.psam.
# 1669674 variants loaded from
# corriellnetpd_geno/corriell_chr2_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:46:55 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr3_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr3_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr3_EUR_release3
#
# Start time: Sun Jul  2 18:46:55 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr3_EUR_release3.psam.
# 1415204 variants loaded from
# corriellnetpd_geno/corriell_chr3_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:47:00 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr4_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr4_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr4_EUR_release3
#
# Start time: Sun Jul  2 18:47:00 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr4_EUR_release3.psam.
# 1415906 variants loaded from
# corriellnetpd_geno/corriell_chr4_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:47:05 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr5_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr5_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr5_EUR_release3
#
# Start time: Sun Jul  2 18:47:05 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr5_EUR_release3.psam.
# 1271472 variants loaded from
# corriellnetpd_geno/corriell_chr5_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:47:22 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr6_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr6_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr6_EUR_release3
#
# Start time: Sun Jul  2 18:47:22 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr6_EUR_release3.psam.
# 1265523 variants loaded from
# corriellnetpd_geno/corriell_chr6_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:48:05 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr7_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr7_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr7_EUR_release3
#
# Start time: Sun Jul  2 18:48:05 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr7_EUR_release3.psam.
# 1151156 variants loaded from
# corriellnetpd_geno/corriell_chr7_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:48:13 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr8_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr8_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr8_EUR_release3
#
# Start time: Sun Jul  2 18:48:13 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr8_EUR_release3.psam.
# 1095709 variants loaded from
# corriellnetpd_geno/corriell_chr8_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:48:38 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr9_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr9_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr9_EUR_release3
#
# Start time: Sun Jul  2 18:48:38 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr9_EUR_release3.psam.
# 859295 variants loaded from corriellnetpd_geno/corriell_chr9_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:48:42 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr10_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr10_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr10_EUR_release3
#
# Start time: Sun Jul  2 18:48:42 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr10_EUR_release3.psam.
# 992520 variants loaded from
# corriellnetpd_geno/corriell_chr10_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:49:30 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr11_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr11_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr11_EUR_release3
#
# Start time: Sun Jul  2 18:49:30 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr11_EUR_release3.psam.
# 970345 variants loaded from
# corriellnetpd_geno/corriell_chr11_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:29 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr12_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr12_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr12_EUR_release3
#
# Start time: Sun Jul  2 18:50:29 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr12_EUR_release3.psam.
# 944368 variants loaded from
# corriellnetpd_geno/corriell_chr12_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:43 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr13_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr13_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr13_EUR_release3
#
# Start time: Sun Jul  2 18:50:44 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr13_EUR_release3.psam.
# 711517 variants loaded from
# corriellnetpd_geno/corriell_chr13_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:46 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr14_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr14_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr14_EUR_release3
#
# Start time: Sun Jul  2 18:50:46 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr14_EUR_release3.psam.
# 634312 variants loaded from
# corriellnetpd_geno/corriell_chr14_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:48 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr15_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr15_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr15_EUR_release3
#
# Start time: Sun Jul  2 18:50:48 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr15_EUR_release3.psam.
# 570161 variants loaded from
# corriellnetpd_geno/corriell_chr15_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:50 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr16_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr16_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr16_EUR_release3
#
# Start time: Sun Jul  2 18:50:50 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr16_EUR_release3.psam.
# 622521 variants loaded from
# corriellnetpd_geno/corriell_chr16_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:50:56 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr17_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr17_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr17_EUR_release3
#
# Start time: Sun Jul  2 18:50:57 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr17_EUR_release3.psam.
# 557796 variants loaded from
# corriellnetpd_geno/corriell_chr17_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:51:18 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr18_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr18_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr18_EUR_release3
#
# Start time: Sun Jul  2 18:51:18 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr18_EUR_release3.psam.
# 558948 variants loaded from
# corriellnetpd_geno/corriell_chr18_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:51:50 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr19_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr19_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr19_EUR_release3
#
# Start time: Sun Jul  2 18:51:51 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr19_EUR_release3.psam.
# 449087 variants loaded from
# corriellnetpd_geno/corriell_chr19_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:52:17 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr20_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr20_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr20_EUR_release3
#
# Start time: Sun Jul  2 18:52:17 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr20_EUR_release3.psam.
# 445947 variants loaded from
# corriellnetpd_geno/corriell_chr20_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:52:44 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr21_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr21_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr21_EUR_release3
#
# Start time: Sun Jul  2 18:52:44 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr21_EUR_release3.psam.
# 269941 variants loaded from
# corriellnetpd_geno/corriell_chr21_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:53:00 2023
# PLINK v2.00a3.3LM AVX2 Intel (3 Jun 2022)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to corriellnetpd_geno/corriell_chr22_EUR_release3.log.
# Options in effect:
#   --export vcf
#   --out corriellnetpd_geno/corriell_chr22_EUR_release3
#   --pfile corriellnetpd_geno/corriell_chr22_EUR_release3
#
# Start time: Sun Jul  2 18:53:00 2023
# 60283 MiB RAM detected; reserving 30141 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 422 samples (156 females, 266 males; 422 founders) loaded from
# corriellnetpd_geno/corriell_chr22_EUR_release3.psam.
# 271576 variants loaded from
# corriellnetpd_geno/corriell_chr22_EUR_release3.pvar.
# 1 binary phenotype loaded (422 cases, 0 controls).
# done.
# End time: Sun Jul  2 18:53:16 2023

# %% [markdown]
# # Push files to the WD bucket

# %% [markdown]
# #### Copy to your path

# %%
shell_do(f'gsutil -u {BILLING_PROJECT_ID} -m cp {WORK_DIR}corriellnetpd_geno/* {NEXTFLOW_WD_BUCKET}/long-gwas/DATA/amc/netpdcorriell/geno/')
# Out:
# Executing: gsutil -u terra-05d0f4c6 -m cp /home/jupyter/longwas_workdir/corriellnetpd_geno/* gs://long-gwas/long-gwas/DATA/amc/netpdcorriell/geno/
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr10_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr10_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr10_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr10_EUR_release3.pvar [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr10_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr11_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr11_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr11_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr11_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr11_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr12_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr12_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr12_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr12_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr12_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr13_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr13_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr13_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr13_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr13_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr14_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr14_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr14_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr14_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr14_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr15_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr15_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr15_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr15_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr15_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr16_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr16_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr16_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr16_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr16_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr17_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr17_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr17_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr17_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr18_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr17_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr18_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr19_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr18_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr18_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr18_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr19_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr19_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr19_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr19_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr20_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr21_EUR_release3.log [Content-Type=application/octet-stream]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr1_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr20_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr20_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr20_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr21_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr21_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr20_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr21_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr22_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr22_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr21_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr22_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr22_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr3_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr22_EUR_release3.log [Content-Type=application/octet-stream]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr2_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.vcf [Content-Type=text/vcard]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr4_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.vcf [Content-Type=text/vcard]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr5_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.vcf [Content-Type=text/vcard]...
# Resuming upload for file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr6_EUR_release3.vcf
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr7_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr7_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr7_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr7_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr7_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr8_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr8_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr8_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr8_EUR_release3.vcf [Content-Type=text/vcard]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr8_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr9_EUR_release3.log [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr9_EUR_release3.pgen [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr9_EUR_release3.psam [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr9_EUR_release3.pvar [Content-Type=application/octet-stream]...
# Copying file:///home/jupyter/longwas_workdir/corriellnetpd_geno/corriell_chr9_EUR_release3.vcf [Content-Type=text/vcard]...
# \ [110/110 files][ 37.7 GiB/ 37.7 GiB] 100% Done 107.9 MiB/s ETA 00:00:00
# Operation completed over 110 objects/37.7 GiB.

# %% [markdown]
# # Process clinical data
#
# We need to generate two files
# - Phenotype file
#
# - Covariates file

# %% [markdown]
# ### Filter out patients missing genotype data

# %%
sam = pd.read_csv(f'{WORK_DIR}corriellnetpd_geno/corriell_chr10_EUR_release3.psam', sep = "\t")
print(sam.shape)

# %%
genoids = sam.iloc[:,0].to_list()
netpd_qc = netpdcorriell[netpdcorriell['GP2sampleID'].isin(genoids)].reset_index(drop=True).copy()

# %%
netpd_qc_nona = netpd_qc[~netpd_qc['updrs_part_iii_summary_score'].isna()]
netpd_qc_nona = netpd_qc_nona.rename(columns={"GP2sampleID": "IID"})
netpd_qc_nona.head()

# %% [markdown]
# ### Get phenofile

# %%
pheno = netpd_qc_nona[['IID', 'visit_name', 
                       'updrs_part_ii_summary_score', 'updrs_part_iii_summary_score']]

print('Number UPDRS II NAs: ', pheno['updrs_part_ii_summary_score'].isna().sum().sum())
print('Number UPDRS III NAs: ', pheno['updrs_part_iii_summary_score'].isna().sum().sum())

#pheno.head()
pheno.to_csv(f'{WORK_DIR}clinical_qc/updrspheno_netpdCorriell.tsv', sep="\t")
# Out:
# Number UPDRS II NAs:  0
# Number UPDRS III NAs:  0

# %% [markdown]
# ### Get covars file

# %%
covars = netpd_qc_nona[['IID', 'age_at_baseline', 'sex']]\
                      .drop_duplicates(subset='IID', keep="first")
covars.to_csv(f'{WORK_DIR}clinical_qc/covars_netpdCorriell.tsv', sep="\t")

# %% [markdown]
# ### Copy data to the bucket

# %%
#os.listdir(f'{WORK_DIR}clinical_qc')
shell_do(f'gsutil -u {BILLING_PROJECT_ID} -m cp {WORK_DIR}/clinical_qc/* {NEXTFLOW_WD_BUCKET}/long-gwas/DATA/amc/netpdcorriell/clinical/')
# Out:
# Executing: gsutil -u terra-05d0f4c6 -m cp /home/jupyter/longwas_workdir//clinical_qc/* gs://long-gwas/long-gwas/DATA/amc/netpdcorriell/clinical/
# Copying file:///home/jupyter/longwas_workdir//clinical_qc/updrspheno_netpdCorriell.tsv [Content-Type=text/tab-separated-values]...
# Copying file:///home/jupyter/longwas_workdir//clinical_qc/covars_netpdCorriell.tsv [Content-Type=text/tab-separated-values]...
# / [2/2 files][106.1 KiB/106.1 KiB] 100% Done
# Operation completed over 2 objects/106.1 KiB.
